# %%
import pandas as pd
import numpy as np

# %%
# !dir
# Out:
#  Volume in drive C is OS
#  Volume Serial Number is 68D7-27A6
#
#  Directory of C:\hello world\ba\pandas_docs (1)
#
# 10/15/2023  11:35 PM    <DIR>          .
# 10/15/2023  07:25 PM    <DIR>          ..
# 10/15/2023  07:29 PM    <DIR>          .ipynb_checkpoints
# 10/15/2023  10:36 AM        46,131,166 archive (1).zip
# 10/15/2023  10:38 AM        13,133,485 archive (2).zip
# 10/15/2023  10:39 AM           285,582 archive (3).zip
# 10/15/2023  10:34 AM            18,961 archive.zip
# 07/31/2023  10:59 AM           307,392 ASSIGNMENT 1.ipynb
# 08/07/2023  09:16 AM           344,981 ASSIGNMENT 2.ipynb
# 08/13/2023  12:17 PM           146,396 ASSIGNMENT3.ipynb
# 07/23/2023  05:31 PM               111 csv_mindex.csv
# 08/08/2023  09:42 AM           210,776 DATA ANALYSIS - WRK1.ipynb
# 07/24/2023  09:58 AM                87 data4new.csv
# 08/22/2023  09:21 AM    <DIR>          data_scientist_salary
# 08/22/2023  09:22 AM                22 data_scientist_salary.zip
# ...

# %%
survey=pd.read_csv("survey_results_public.csv",index_col=[0])

# %%
survey
# Out:
#                                                    MainBranch Hobbyist  \
# Respondent
# 1                      I am a student who is learning to code      Yes
# 2                      I am a student who is learning to code       No
# 3           I am not primarily a developer, but I write co...      Yes
# 4                              I am a developer by profession       No
# 5                              I am a developer by profession      Yes
# ...                                                       ...      ...
# 88377                                                     NaN      Yes
# 88601                                                     NaN       No
# 88802                                                     NaN       No
# 88816                                                     NaN       No
# 88863                                                     NaN      Yes
#
#                                                   OpenSourcer  \
# Respondent
# ...

# %%
survey.columns
# Out:
# Index(['MainBranch', 'Hobbyist', 'OpenSourcer', 'OpenSource', 'Employment',
#        'Country', 'Student', 'EdLevel', 'UndergradMajor', 'EduOther',
#        'OrgSize', 'DevType', 'YearsCode', 'Age1stCode', 'YearsCodePro',
#        'CareerSat', 'JobSat', 'MgrIdiot', 'MgrMoney', 'MgrWant', 'JobSeek',
#        'LastHireDate', 'LastInt', 'FizzBuzz', 'JobFactors', 'ResumeUpdate',
#        'CurrencySymbol', 'CurrencyDesc', 'CompTotal', 'CompFreq',
#        'ConvertedComp', 'WorkWeekHrs', 'WorkPlan', 'WorkChallenge',
#        'WorkRemote', 'WorkLoc', 'ImpSyn', 'CodeRev', 'CodeRevHrs', 'UnitTests',
#        'PurchaseHow', 'PurchaseWhat', 'LanguageWorkedWith',
#        'LanguageDesireNextYear', 'DatabaseWorkedWith',
#        'DatabaseDesireNextYear', 'PlatformWorkedWith',
#        'PlatformDesireNextYear', 'WebFrameWorkedWith',
#        'WebFrameDesireNextYear', 'MiscTechWorkedWith',
#        'MiscTechDesireNextYear', 'DevEnviron', 'OpSys', 'Containers',
# ...

# %% [markdown]
# #### groupby country to check students

# %%
data1=survey.groupby('Student')

# %%
data1['Country'].value_counts()
# Out:
# Student         Country
# No              United States     17878
#                 India              5443
#                 United Kingdom     4957
#                 Germany            4210
#                 Canada             2703
#                                   ...
# Yes, part-time  Sierra Leone          1
#                 Sudan                 1
#                 Swaziland             1
#                 Turkmenistan          1
#                 Yemen                 1
# Name: Country, Length: 471, dtype: int64

# %%
country_ind=survey.groupby('Country')

# %%
nw=country_ind.get_group('India')
nw
# Out:
#                                         MainBranch Hobbyist  \
# Respondent
# 8                      I code primarily as a hobby      Yes
# 10                  I am a developer by profession      Yes
# 15          I am a student who is learning to code      Yes
# 50                  I am a developer by profession      Yes
# 65                  I am a developer by profession      Yes
# ...                                            ...      ...
# 77339                                          NaN      Yes
# 79795                                          NaN      Yes
# 83862                                          NaN      Yes
# 84299                                          NaN      Yes
# 86012                                          NaN      Yes
#
#                                                   OpenSourcer  \
# Respondent
# 8                                     Less than once per year
# 10                                 Once a month or more often
# ...

# %% [markdown]
# ### 2.to get country by details of people satisfied in job

# %%
job_sat=survey.groupby("JobSat")
job_sat['Country'].value_counts()
# Out:
# JobSat                              Country
# Neither satisfied nor dissatisfied  United States           1524
#                                     India                   1272
#                                     Germany                  523
#                                     United Kingdom           514
#                                     Canada                   278
#                                                             ...
# Very satisfied                      Oman                       1
#                                     San Marino                 1
#                                     Swaziland                  1
#                                     Syrian Arab Republic       1
#                                     Timor-Leste                1
# Name: Country, Length: 707, dtype: int64

# %% [markdown]
# ### 3.calc the mean of a numeric column within in each grp

# %%
cntry_grp=survey.groupby("Country")

# %%
cntry_grp['ConvertedComp'].mean()
# Out:
# Country
# Afghanistan                             101953.333333
# Albania                                  21833.700000
# Algeria                                  34924.047619
# Andorra                                 160931.000000
# Angola                                    7764.000000
#                                             ...
# Venezuela, Bolivarian Republic of...     14581.627907
# Viet Nam                                 17233.436782
# Yemen                                    16909.166667
# Zambia                                   10075.375000
# Zimbabwe                                 34046.666667
# Name: ConvertedComp, Length: 179, dtype: float64

# %% [markdown]
# ### 4.find total count of records in each grp

# %%
cntry_grp['Student'].get_group('India').value_counts()
# Out:
# No                5443
# Yes, full-time    2944
# Yes, part-time     318
# Name: Student, dtype: int64

# %% [markdown]
# ### 5.calc the max value in a different column for each grp

# %%
cntry_grp['ConvertedComp'].get_group('India').max()
# Out:
# 2000000.0

# %% [markdown]
# ### 6. group data by multiple columns and calc the sum

# %%
cntry_grp['ConvertedComp'].get_group('India').sum()
# Out:
# 112202602.0

# %% [markdown]
# ### 7.calc the average values of multiple columns for grp

# %%
job_sat['ConvertedComp'].mean()
# Out:
# JobSat
# Neither satisfied nor dissatisfied    106379.734029
# Slightly dissatisfied                 110360.994075
# Slightly satisfied                    123414.081801
# Very dissatisfied                     120739.585703
# Very satisfied                        147949.915596
# Name: ConvertedComp, dtype: float64

# %% [markdown]
# ### 8.grp data by a column and calc the median of a different column within each grp

# %%
cntry_grp['ConvertedComp'].get_group('India').median()
# Out:
# 10080.0

# %% [markdown]
# ###  9.calc the sum of a numeric column and rename the resulting column

# %%
survey.rename(columns={'ConvertedComp':'Salary'})
# Out:
#                                                    MainBranch Hobbyist  \
# Respondent
# 1                      I am a student who is learning to code      Yes
# 2                      I am a student who is learning to code       No
# 3           I am not primarily a developer, but I write co...      Yes
# 4                              I am a developer by profession       No
# 5                              I am a developer by profession      Yes
# ...                                                       ...      ...
# 88377                                                     NaN      Yes
# 88601                                                     NaN       No
# 88802                                                     NaN       No
# 88816                                                     NaN       No
# 88863                                                     NaN      Yes
#
#                                                   OpenSourcer  \
# Respondent
# ...

# %%
cntry_grp['ConvertedComp'].get_group('Germany').sum()
# Out:
# 412772508.0

# %% [markdown]
# ### 9.filter out grps with a min count of records

# %%
em_grp=survey.groupby("Employment")

# %%
em_grp["Age"].min()
# Out:
# Employment
# Employed full-time                                      1.0
# Employed part-time                                      2.0
# Independent contractor, freelancer, or self-employed    1.0
# Not employed, and not looking for work                  1.0
# Not employed, but looking for work                      2.0
# Retired                                                 5.0
# Name: Age, dtype: float64

# %% [markdown]
# # salary

# %%
ds_sal=pd.read_csv('ds_salaries.csv')
ds_sal
# Out:
#      Unnamed: 0  work_year experience_level employment_type  \
# 0             0       2020               MI              FT
# 1             1       2020               SE              FT
# 2             2       2020               SE              FT
# 3             3       2020               MI              FT
# 4             4       2020               SE              FT
# ..          ...        ...              ...             ...
# 602         602       2022               SE              FT
# 603         603       2022               SE              FT
# 604         604       2022               SE              FT
# 605         605       2022               SE              FT
# 606         606       2022               MI              FT
#
#                       job_title  salary salary_currency  salary_in_usd  \
# 0                Data Scientist   70000             EUR          79833
# 1    Machine Learning Scientist  260000             USD         260000
# ...

# %%
ds_sal.columns
# Out:
# Index(['Unnamed: 0', 'work_year', 'experience_level', 'employment_type',
#        'job_title', 'salary', 'salary_currency', 'salary_in_usd',
#        'employee_residence', 'remote_ratio', 'company_location',
#        'company_size'],
#       dtype='object')

# %% [markdown]
# ### 10.min salary for employment

# %%
emp_typ=ds_sal.groupby('employment_type')

# %%
ds_sal['employment_type'].unique()
# Out:
# array(['FT', 'CT', 'PT', 'FL'], dtype=object)

# %%
emp_typ['salary'].min()
# Out:
# employment_type
# CT    29000
# FL    12000
# FT     4000
# PT     8760
# Name: salary, dtype: int64

# %% [markdown]
# ### 11.salary range

# %%
ds_sal['experience_level'].unique()
# Out:
# array(['MI', 'SE', 'EN', 'EX'], dtype=object)

# %%
exp=ds_sal.groupby('experience_level')
exp['salary'].median()
# Out:
# experience_level
# EN     68500.0
# EX    187500.0
# MI     85000.0
# SE    140000.0
# Name: salary, dtype: float64

# %% [markdown]
# ### 12.grouping by employee residnc and job

# %%
em_res=ds_sal.groupby('employee_residence')
em_res['job_title'].value_counts()
# Out:
# employee_residence  job_title
# AE                  Machine Learning Engineer             2
#                     Lead Data Scientist                   1
# AR                  Data Science Engineer                 1
# AT                  Data Engineer                         1
#                     Data Scientist                        1
#                                                          ..
# US                  Principal Data Analyst                1
#                     Staff Data Scientist                  1
# VN                  Applied Machine Learning Scientist    1
#                     Data Analytics Engineer               1
#                     Data Scientist                        1
# Name: job_title, Length: 196, dtype: int64

# %% [markdown]
# ### 13.eploy res and compny loc

# %%
em_res['company_location'].get_group("US").value_counts()
# Out:
# US    330
# FR      1
# CA      1
# Name: company_location, dtype: int64

# %% [markdown]
# ### 14,jobtitl and max sal of  Data Scientist

# %%
jobT=ds_sal.groupby("job_title")
jobT["salary"].get_group("Data Scientist").max()
# Out:
# 30400000

# %% [markdown]
# ### 15.median sal according to compny size

# %%
cmpny_sz=ds_sal.groupby("company_size")
cmpny_sz['salary_in_usd'].median()
# Out:
# company_size
# L    100000.0
# M    113188.0
# S     65000.0
# Name: salary_in_usd, dtype: float64

# %% [markdown]
# # TITANIC

# %%
ttnc=pd.read_csv('Titanic-Dataset.xls',index_col=[0])
ttnc
# Out:
#              Survived  Pclass  \
# PassengerId
# 1                   0       3
# 2                   1       1
# 3                   1       3
# 4                   1       1
# 5                   0       3
# ...               ...     ...
# 887                 0       2
# 888                 1       1
# 889                 0       3
# 890                 1       1
# 891                 0       3
#
#                                                           Name     Sex   Age  \
# PassengerId
# 1                                      Braund, Mr. Owen Harris    male  22.0
# 2            Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0
# 3                                       Heikkinen, Miss. Laina  female  26.0
# 4                 Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0
# 5                                     Allen, Mr. William Henry    male  35.0
# ...                                                        ...     ...   ...
# ...

# %%
ttnc.columns
# Out:
# Index(['Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp', 'Parch', 'Ticket',
#        'Fare', 'Cabin', 'Embarked'],
#       dtype='object')

# %% [markdown]
# ### 16.count of sex in pclass

# %%
pclass=ttnc.groupby('Pclass')
pclass['Sex'].value_counts()
# Out:
# Pclass  Sex
# 1       male      122
#         female     94
# 2       male      108
#         female     76
# 3       male      347
#         female    144
# Name: Sex, dtype: int64

# %% [markdown]
# ### 17.median age in pclass

# %%
pclass['Age'].get_group(1).median()
# Out:
# 37.0

# %% [markdown]
# ### 18.survived rate in pclass

# %%
pclass['Survived'].value_counts()
# Out:
# Pclass  Survived
# 1       1           136
#         0            80
# 2       0            97
#         1            87
# 3       0           372
#         1           119
# Name: Survived, dtype: int64

# %% [markdown]
# ### 19.fare for 2nd class

# %%
pclass['Fare'].get_group(2).value_counts()
# Out:
# 13.0000    42
# 26.0000    29
# 10.5000    24
# 21.0000     6
# 0.0000      6
# 26.2500     6
# 73.5000     5
# 39.0000     4
# 23.0000     4
# 13.5000     4
# 11.5000     4
# 33.0000     3
# 12.3500     3
# 18.7500     3
# 41.5792     3
# 27.7500     3
# 65.0000     2
# 29.0000     2
# 24.0000     2
# 19.5000     2
# 14.5000     2
# 37.0042     2
# 27.0000     2
# 36.7500     2
# 30.0708     2
# 30.0000     1
# 12.6500     1
# 13.8625     1
# 15.0000     1
# 13.7917     1
# 32.5000     1
# 12.2750     1
# 12.0000     1
# 27.7208     1
# 14.0000     1
# 12.8750     1
# 16.0000     1
# 15.0500     1
# 15.7500     1
# 12.5250     1
# 15.0458     1
# 13.8583     1
# Name: Fare, dtype: int64

# %% [markdown]
# ### 20.embarked survivors

# %%
embark=ttnc.groupby('Embarked')
embark['Survived'].value_counts()
# Out:
# Embarked  Survived
# C         1            93
#           0            75
# Q         0            47
#           1            30
# S         0           427
#           1           217
# Name: Survived, dtype: int64

# %% [markdown]
# ### 21.survived persons age

# %%
survv=ttnc.groupby("Survived")
survv['Age'].get_group(1)
# Out:
# PassengerId
# 2      38.0
# 3      26.0
# 4      35.0
# 9      27.0
# 10     14.0
#        ...
# 876    15.0
# 880    56.0
# 881    25.0
# 888    19.0
# 890    26.0
# Name: Age, Length: 342, dtype: float64

# %% [markdown]
# # IRIS

# %%
iris=pd.read_csv("Iris.csv.xls")
iris
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 0      1            5.1           3.5            1.4           0.2
# 1      2            4.9           3.0            1.4           0.2
# 2      3            4.7           3.2            1.3           0.2
# 3      4            4.6           3.1            1.5           0.2
# 4      5            5.0           3.6            1.4           0.2
# ..   ...            ...           ...            ...           ...
# 145  146            6.7           3.0            5.2           2.3
# 146  147            6.3           2.5            5.0           1.9
# 147  148            6.5           3.0            5.2           2.0
# 148  149            6.2           3.4            5.4           2.3
# 149  150            5.9           3.0            5.1           1.8
#
#             Species
# 0       Iris-setosa
# 1       Iris-setosa
# 2       Iris-setosa
# 3       Iris-setosa
# 4       Iris-setosa
# ..              ...
# ...

# %% [markdown]
# ### 22.min SepalLengthCm of Iris-setosa
